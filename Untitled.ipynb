# %%
import json
import math
import os
import numpy as np
from PIL import Image
import xml.etree.ElementTree as ET
import base64
import zlib
import struct
import time
import csv
import datetime
import xml.etree.ElementTree as ET
import pdb
from pymongo import MongoClient  # Database connector
from random import shuffle
import pickle
import os
import random
import itertools
from itertools import combinations 
from bs4 import BeautifulSoup
EARTH_RADIUS = 6371000  # Radius in meters of Earth
GOOGLE_CAR_CAMERA_HEIGHT = 3 # ballpark estimate of the number of meters that camera is off the ground
STEVE_API_KEY = "AIzaSyBnxlcMIMTACiXOOwopa8VAoseY_59pq8w"
STEVE_API_STATIC_KEY = "AIzaSyCou-82BbEst0L9WRXkNvpMcAnGH9mDAH8"
from bson import ObjectId
import shutil

# %%
lines=[]
with open("/scratch/gits/datasets/VOC/Pasadena/ImageSets/Main/reid_neu/train.txt") as file:
    for line in file: 
        line = line.strip() #or some other preprocessing
        lines.append(line.split("     ")) #storing everything in memory!
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2))

# %%
for x in lines:
    panofile = open("/scratch/gits/datasets/VOC/Pasadena/Annotations_Multi/"+x[0]+".xml", "r")
    panofile1 = open("/scratch/gits/datasets/VOC/Pasadena/Annotations_Multi/"+x[1]+".xml", "r")
    soup = BeautifulSoup(panofile, 'xml')
    soup1 = BeautifulSoup(panofile1, 'xml')
    panofile.close()
    panofile1.close()
    sett1 = []
    sett2 = []

    for idd in soup.find_all('ID'):
        sett1.append(idd.text)
    for idd1 in soup1.find_all('ID'):
        sett2.append(idd1.text)
    print(x)
    print("int: ", intersection(sett1, sett2)[0])
    print("------------------------")
# Out:
# ['hCuaNAQUiFACKrWErVi2vQ_z2', 'YykrxZZZpFe3vL9bQu2svQ_z2']
# int:  100013
# ------------------------
# ['tTMNGsr9FEtg2fOhRumizA_z2', '0oiLvG-wSXzsnOiXarSGGg_z2']
# int:  100548
# ------------------------
# ['hgAlVl4Vj8TQywGHtPrFyw_z2', 'afyueMjppiKrDjaR_Krczg_z2']
# int:  102906
# ------------------------
# ['BTHGkrCY_OdVsjjAHfP0qg_z2', 'ZUHlhMph73LeJVi6Z8zdBg_z2']
# int:  104422
# ------------------------
# ['r_D8OmFxCBL3pHX7ep5T8w_z2', 'Jto4QWQF89q-0gbusANfHQ_z2']
# int:  100015
# ------------------------
# ['KQirKXAFV2CG5czz_s6Y9g_z2', 'gYE3rFfK0drebC-7KwCEEw_z2']
# int:  106427
# ------------------------
# ['BPHzVQm96bhkjlwv6LJYnw_z2', 'QsRo4jJfz0OP49PU6hx2TA_z2']
# int:  105982
# ------------------------
# ['BZylwS6ml0LcgYpduWwsvg_z2', 'CHyKdWw3sZoVofjr0OQF3A_z2']
# int:  105699
# ------------------------
# ['-F6ikm1byQlxHuZueRv2Lg_z2', 'EnlsGlZ7u6eEzSEqo4JQ7w_z2']
# int:  103334
# ------------------------
# ['91qNbH8ByLvhocugN7G5ng_z2', 'Kmn3hhdi9-AUyNQ5RXJ1SA_z2']
# ...
